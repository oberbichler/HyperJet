# %%
import hyperjet as hj

# %%
a, b = hj.HyperJet.variables([3, 6])

result = (a * b) / (a - b)

# %%
result.f
# Out:
# -6.0

# %%
result.g
# Out:
# array([-4.,  1.])

# %%
result.h
# Out:
# array([[-2.66666667,  1.33333333],
#        [ 1.33333333, -0.66666667]])
